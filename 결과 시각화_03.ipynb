# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.collections as collections
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %matplotlib inline

# %%
def RMSE(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    return np.sqrt(mse)

# %%
def R2(y_true, y_pred):
    R2_score = r2_score(y_true, y_pred, multioutput='raw_values')
    return R2_score

# %%
cd /Users/jinsungpark/Desktop
# Out:
# /Users/jinsungpark/Desktop

# %% [markdown]
# # 기상데이터와 TP,TN

# %%
other = pd.read_excel('/Users/jinsungpark/Desktop/시각화분석용/DS_NG_분석용.xlsx')
other_nor = pd.read_excel('/Users/jinsungpark/Desktop/시각화분석용/DS_NG_분석용_노말.xlsx')

# %%
other.info()
other_nor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         227 non-null    object
#  1   DS_TN        227 non-null    float64
#  2   SeoBu_TN     227 non-null    float64
#  3   SungSeo_TN   227 non-null    float64
#  4   GumHo_TN     227 non-null    float64
#  5   DS_TP        227 non-null    float64
#  6   SeoBu_TP     227 non-null    float64
#  7   SungSeo_TP   227 non-null    float64
#  8   GumHo_TP     227 non-null    float64
#  9   DaeGu_Rain   227 non-null    float64
#  10  DaeGu_Solar  227 non-null    float64
#  11  NG_TN        227 non-null    float64
#  12  NG_TP        227 non-null    float64
#  13  NG_Temp      227 non-null    float64
# dtypes: float64(13), object(1)
# memory usage: 25.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 14 columns):
# ...

# %% [markdown]
# ### 다사-논공

# %%
#노멀라이즈 안한것
x = range(len(other.DS_TP))
y1 = other.NG_TP
y2 = other.DaeGu_Rain
y3 = other.DaeGu_Solar

fig, ax1 = plt.subplots(figsize=(8, 3))
ax1.plot(x, y1, 'r-', label = 'NonGong_TP')
# plt.legend(loc='upper left')
ax2 = ax1.twinx()
ax2.plot(x, y2, 'b-', label = 'DaeGu_Rain')
ax2.plot(x, y3, 'green', label = 'DaeGu_Solar')
ax1.set_ylim(0,0.18)
ax2.set_ylim(-10,300)
# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# plt.ylim(0,0.18)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
# #노멀라이즈 한것
# x = range(len(other_nor.DS_TP))
# ny1 = other_nor.NG_TP
# ny2 = other_nor.DaeGu_Rain
# ny3 = other_nor.DaeGu_Solar

# fig2, ax3 = plt.subplots(figsize=(15, 4))
# ax3.plot(x, ny1, 'r-', label = 'Normalized_NonGong_TP')
# ax3.plot(x, ny2, 'b-', label = 'Normalized_DaeGu_Rain')
# ax3.plot(x, ny3, 'green', label = 'Normalized_DaeGu_Solar')

# ax3.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='up left')
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
x = range(len(other.DS_TN))
y1 = other.NG_TN
y2 = other.DaeGu_Rain
y3 = other.DaeGu_Solar

fig, ax1 = plt.subplots(figsize=(8, 3))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'purple', label = 'NonGong_TN')
ax2.plot(x, y2, 'b-', label = 'DaeGu_Rain')
ax2.plot(x, y3, 'green', label = 'DaeGu_Solar')
ax1.set_ylim(1,7)
ax2.set_ylim(-10,300)
# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
plt.show()
# plt.savefig('DS_NG_TN_weather.png', dpi = 200,  bbox_inches='tight')

# %%
# #노멀라이즈 한것
# x = range(len(other_nor.DS_TN))
# ny1 = other_nor.NG_TN
# ny2 = other_nor.DaeGu_Rain
# ny3 = other_nor.DaeGu_Solar

# fig2, ax3 = plt.subplots(figsize=(15, 4))
# ax3.plot(x, ny1, 'r-', label = 'Normalized_NonGong_TN')
# ax3.plot(x, ny2, 'b-', label = 'Normalized_DaeGu_Rain')
# ax3.plot(x, ny3, 'green', label = 'Normalized_DaeGu_Solar')

# ax3.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='up left')
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
#노멀라이즈 안한것
x = range(len(other.DS_TP))
y1 = other.NG_TP
y2 = other.NG_Temp

fig, ax1 = plt.subplots(figsize=(8, 3))
ax1.plot(x, y1, 'r-', label = 'NonGong_TP')

ax2 = ax1.twinx()
ax2.plot(x, y2, 'b-', label = 'NG_Temp')

# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(0,0.18)
ax2.set_ylim(0,36)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
#노멀라이즈 안한것
x = range(len(other.DS_TN))
y1 = other.NG_TN
y2 = other.NG_Temp

fig, ax1 = plt.subplots(figsize=(8, 3))
ax1.plot(x, y1, 'purple', label = 'NonGong_TN')

ax2 = ax1.twinx()
ax2.plot(x, y2, 'b-', label = 'NG_Temp')

# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(1,7)
ax2.set_ylim(0,36)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
# #노멀라이즈 한것
# x = range(len(other_nor.DS_TP))
# ny1 = other_nor.NG_TP
# ny2 = other_nor.NG_TN
# ny3 = other_nor.NG_Temp

# fig2, ax3 = plt.subplots(figsize=(15, 4))
# ax3.plot(x, ny1, 'r-', label = 'Normalized_NonGong_TP')
# ax3.plot(x, ny2, 'b-', label = 'Normalized_NonGong_TP')
# ax3.plot(x, ny3, 'green', label = 'Normalized_NonGong_Temp')

# ax3.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
# x = range(len(other.NG_TP))
# y = other.NG_TP
# y1 = other.DS_TP
# y2 = other.SeoBu_TP
# y3 = other.SungSeo_TP
# y4 = other.GumHo_TP

# fig, ax1 = plt.subplots(figsize=(15, 4))

# # ax2 = ax1.twinx()
# ax1.plot(x, y, 'r-', label = 'NonGong_TP')
# ax1.plot(x, y1, 'skyblue', label = 'DaSa_TP')
# ax1.plot(x, y2, 'orange', label = 'SeoBu_TP')
# ax1.plot(x, y3, 'g-', label = 'SungSeo_TP')
# ax1.plot(x, y4, 'b-', label = 'GumHo_TP')

# # ax2.plot(x, y2, y3, 'b-')

# # ax1.set_xlabel('X data')
# # ax1.set_ylabel('TP(mg/L)',color='r')
# # ax2.set_ylabel('강',color='b')
# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.ylim(0,0.3)
# plt.legend(loc='upper left')
# # loc='upper right'
# plt.show()
# plt.savefig('DS_NG_TP_pollutant.png', dpi = 200,  bbox_inches='tight')

# %%
# x = range(len(other.NG_TN))
# y = other.NG_TN
# y1 = other.DS_TN
# y2 = other.SeoBu_TN
# y3 = other.SungSeo_TN
# y4 = other.GumHo_TN

# fig, ax1 = plt.subplots(figsize=(15, 4))

# # ax2 = ax1.twinx()
# ax1.plot(x, y, 'r-', label = 'NonGong_TN')
# ax1.plot(x, y1, 'skyblue', label = 'DaSa_TN')
# ax1.plot(x, y2, 'orange', label = 'SeoBu_TN')
# ax1.plot(x, y3, 'g-', label = 'SungSeo_TN')
# ax1.plot(x, y4, 'b-', label = 'GumHo_TN')

# # ax2.plot(x, y2, y3, 'b-')

# # ax1.set_xlabel('X data')
# # ax1.set_ylabel('TP(mg/L)',color='r')
# # ax2.set_ylabel('강',color='b')
# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# # loc='upper right'
# plt.show()
# plt.savefig('DS_NG_TN_pollutant.png', dpi = 200,  bbox_inches='tight')

# %% [markdown]
# ### 덕곡-함안

# %%
another = pd.read_excel('/Users/jinsungpark/Desktop/시각화분석용/DG_HA_분석용.xlsx')
another_nor = pd.read_excel('/Users/jinsungpark/Desktop/시각화분석용/DG_HA_분석용_노말.xlsx')

# %%
another.info()
another_nor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            349 non-null    object
#  1   DukGok_TN       349 non-null    float64
#  2   ChilSeo_TN      349 non-null    float64
#  3   HwangGang_TN    349 non-null    float64
#  4   SanBan_TN       349 non-null    float64
#  5   NamGang_TN      349 non-null    float64
#  6   GyeaSung_TN     349 non-null    float64
#  7   GwangRyeo_TN    349 non-null    float64
#  8   ToPyeong_TN     349 non-null    float64
#  9   DukGok_TP       349 non-null    float64
#  10  ChilSeo_TP      349 non-null    float64
#  11  HwangGang_TP    349 non-null    float64
#  12  SanBan_TP       349 non-null    float64
#  13  NamGang_TP      349 non-null    float64
#  14  GyeaSung_TP     349 non-null    float64
#  15  GwangRyeo_TP    349 non-null    float64
#  16  ToPyeong_TP     349 non-null    float64
# ...

# %%
x = range(len(another.HamAn_TP))
y1 = another.HamAn_TP
y2 = another.BukChang_Rain
y3 = another.BukChang_Solar

fig, ax1 = plt.subplots(figsize=(8, 3))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'r-', label = 'HamAn_TP')
ax2.plot(x, y2, 'b-', label = 'BukChang_Rain')
ax2.plot(x, y3, 'g-', label = 'BukChang_Solar')

# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(0,0.18)
ax2.set_ylim(-10,300)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
# #노멀라이즈 한것
# x = range(len(another_nor.HamAn_TP))
# ny1 = another_nor.HamAn_TP
# ny2 = another_nor.BukChang_Rain
# ny3 = another_nor.BukChang_Solar

# fig2, ax3 = plt.subplots(figsize=(15, 4))
# ax3.plot(x, ny1, 'r-', label = 'Normalized_HamAn_TP')
# ax3.plot(x, ny2, 'b-', label = 'Normalized_BukChang_Rain')
# ax3.plot(x, ny3, 'green', label = 'Normalized_BukChang_Solar')

# ax3.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='up left')
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
x = range(len(another.HamAn_TP))
y1 = another.HamAn_TN
y2 = another.BukChang_Rain
y3 = another.BukChang_Solar

fig, ax1 = plt.subplots(figsize=(8, 3))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'purple', label = 'HamAn_TN')
ax2.plot(x, y2, 'b-', label = 'BukChang_Rain')
ax2.plot(x, y3, 'g-', label = 'BukChang_Solar')

# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(1,7)
ax2.set_ylim(-10,300)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
# #노멀라이즈 한것
# x = range(len(another_nor.HamAn_TN))
# ny1 = another_nor.HamAn_TN
# ny2 = another_nor.BukChang_Rain
# ny3 = another_nor.BukChang_Solar

# fig2, ax3 = plt.subplots(figsize=(15, 4))
# ax3.plot(x, ny1, 'r-', label = 'Normalized_HamAn_TN')
# ax3.plot(x, ny2, 'b-', label = 'Normalized_BukChang_Rain')
# ax3.plot(x, ny3, 'green', label = 'Normalized_BukChang_Solar')

# ax3.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='up left')
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
x = range(len(another.HamAn_TP))
y1 = another.HamAn_TP
y2 = another.HamAn_Temp

fig, ax1 = plt.subplots(figsize=(8, 3))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'r-', label = 'HamAn_TP')
ax2.plot(x, y2, 'b-', label = 'HamAn_Temp')

# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(0,0.18)
ax2.set_ylim(0,36)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
x = range(len(another.HamAn_TN))
y1 = another.HamAn_TN
y2 = another.HamAn_Temp

fig, ax1 = plt.subplots(figsize=(8, 3))

ax2 = ax1.twinx()
ax1.plot(x, y1, 'purple', label = 'HamAn_TN')
ax2.plot(x, y2, 'b-', label = 'HamAn_Temp')

# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(1,7)
ax2.set_ylim(0,36)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200

# %%
# #노멀라이즈 한것
# x = range(len(another_nor.HamAn_TP))
# ny1 = another_nor.HamAn_TP
# ny2 = another_nor.HamAn_TN
# ny3 = another_nor.HamAn_Temp

# fig2, ax3 = plt.subplots(figsize=(15, 4))
# ax3.plot(x, ny1, 'r-', label = 'Normalized_HamAn_TP')
# ax3.plot(x, ny2, 'b-', label = 'Normalized_HamAn_TN')
# ax3.plot(x, ny3, 'green', label = 'Normalized_HamAn_Temp')

# ax3.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
# x = range(len(another.HamAn_TP))
# y = another.HamAn_TP
# y1 = another.DukGok_TP
# y2 = another.ChilSeo_TP
# y3 = another.HwangGang_TP
# y4 = another.SanBan_TP
# y5 = another.NamGang_TP
# y6 = another.GyeaSung_TP
# y7 = another.GwangRyeo_TP
# y8 = another.ToPyeong_TP



# fig, ax1 = plt.subplots(figsize=(15, 4))

# # ax2 = ax1.twinx()

# ax1.plot(x, y, 'r-', label = 'HamAn_TP')
# ax1.plot(x, y1, 'skyblue', label = 'DukGok_TP')
# ax1.plot(x, y2, 'orange', label = 'ChilSeo_TP')
# ax1.plot(x, y3, 'green', label = 'HwangGang_TP')
# ax1.plot(x, y4, 'skyblue', label = 'SanBan_TP')
# ax1.plot(x, y5, 'pink', label = 'NamGang_TP')
# ax1.plot(x, y6, 'purple', label = 'GyeaSung_TP')
# ax1.plot(x, y7, 'b-', label = 'GwangRyeo_TP')
# ax1.plot(x, y8, 'lightgreen', label = 'ToPyeong_TP')
# # ax1.set_xlabel('X data')
# # ax1.set_ylabel('TP(mg/L)',color='r')
# # ax2.set_ylabel('강',color='b')
# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper right')
# plt.ylim(0,0.6)
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %%
# x = range(len(another.HamAn_TP))
# y = another.HamAn_TN
# y1 = another.DukGok_TN
# y2 = another.ChilSeo_TN
# y3 = another.HwangGang_TN
# y4 = another.SanBan_TN
# y5 = another.NamGang_TN
# y6 = another.GyeaSung_TN
# y7 = another.GwangRyeo_TN
# y8 = another.ToPyeong_TN



# fig, ax1 = plt.subplots(figsize=(15, 4))

# # ax2 = ax1.twinx()

# ax1.plot(x, y, 'r-', label = 'HamAn_TN')
# ax1.plot(x, y1, 'skyblue', label = 'DukGok_TN')
# ax1.plot(x, y2, 'orange', label = 'ChilSeo_TN')
# ax1.plot(x, y3, 'green', label = 'HwangGang_TN')
# ax1.plot(x, y4, 'skyblue', label = 'SanBan_TN')
# ax1.plot(x, y5, 'pink', label = 'NamGang_TN')
# ax1.plot(x, y6, 'purple', label = 'GyeaSung_TN')
# ax1.plot(x, y7, 'b-', label = 'GwangRyeo_TN')
# ax1.plot(x, y8, 'lightgreen', label = 'ToPyeong_TN')
# # ax1.set_xlabel('X data')
# # ax1.set_ylabel('TP(mg/L)',color='r')
# # ax2.set_ylabel('강',color='b')
# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper right')
# plt.ylim(0,20)
# plt.show()
# # plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# # , dpi = 200

# %% [markdown]
# # 점오염원과 TP,TN

# %% [markdown]
# ### 다사-논공

# %% [markdown]
# ##### TP

# %%
x = range(len(other.NG_TP))
y = other.NG_TP
y1 = other.DS_TP

fig, ax1 = plt.subplots(figsize=(8, 3))

# ax2 = ax1.twinx()
ax1.plot(x, y, 'r-', label = 'NonGong_TP')
ax1.plot(x, y1, 'skyblue', label = 'DaSa_TP')

ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
plt.ylim(0,0.4)
ax1.set_ylim(0,0.18)
plt.show()
# plt.savefig('DS_NG_TP_pollutant.png', dpi = 200,  bbox_inches='tight')

# %%
# x = range(len(other.NG_TP))
# y = other.NG_TP
# y2 = other.SeoBu_TP

# fig, ax1 = plt.subplots(figsize=(15, 4))

# ax1.plot(x, y, 'r-', label = 'NonGong_TP')
# ax1.plot(x, y2, 'orange', label = 'SeoBu_TP')

# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.ylim(0,0.4)
# plt.legend(loc='upper left')

# plt.show()

# %%
# x = range(len(other.NG_TP))
# y = other.NG_TP
# y3 = other.SungSeo_TP

# fig, ax1 = plt.subplots(figsize=(15, 4))

# ax1.plot(x, y, 'r-', label = 'NonGong_TP')
# ax1.plot(x, y3, 'g-', label = 'SungSeo_TP')

# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.ylim(0,0.4)
# plt.legend(loc='upper left')

# plt.show()

# %%
# x = range(len(other.NG_TP))
# y = other.NG_TP
# y4 = other.GumHo_TP

# fig, ax1 = plt.subplots(figsize=(15, 4))

# ax1.plot(x, y, 'r-', label = 'NonGong_TP')
# ax1.plot(x, y4, 'b-', label = 'GumHo_TP')

# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.ylim(0,0.4)
# plt.legend(loc='upper left')

# plt.show()

# %% [markdown]
# ##### TN

# %%
x = range(len(other.NG_TN))
y = other.NG_TN
y1 = other.DS_TN

fig, ax1 = plt.subplots(figsize=(8, 3))

ax1.plot(x, y, 'purple', label = 'NonGong_TN')
ax1.plot(x, y1, 'orange', label = 'DaSa_TN')

ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
ax1.set_ylim(1,7)
plt.show()

# %%
# x = range(len(other.NG_TN))
# y = other.NG_TN
# y2 = other.SeoBu_TN

# fig, ax1 = plt.subplots(figsize=(15, 4))

# # ax2 = ax1.twinx()
# ax1.plot(x, y, 'r-', label = 'NonGong_TN')
# ax1.plot(x, y2, 'orange', label = 'SeoBu_TN')

# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# plt.ylim(0,20)

# plt.show()

# %%
# x = range(len(other.NG_TN))
# y = other.NG_TN
# y3 = other.SungSeo_TN

# fig, ax1 = plt.subplots(figsize=(15, 4))

# # ax2 = ax1.twinx()
# ax1.plot(x, y, 'r-', label = 'NonGong_TN')
# ax1.plot(x, y3, 'g-', label = 'SungSeo_TN')

# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# plt.ylim(0,20)

# plt.show()

# %%
# x = range(len(other.NG_TN))
# y = other.NG_TN
# y4 = other.GumHo_TN

# fig, ax1 = plt.subplots(figsize=(15, 4))

# ax1.plot(x, y, 'r-', label = 'NonGong_TN')
# ax1.plot(x, y4, 'b-', label = 'GumHo_TN')

# ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper left')
# plt.ylim(0,20)

# plt.show()

# %% [markdown]
# ### 덕곡-함안

# %% [markdown]
# ##### TP

# %%
x = range(len(another.HamAn_TP))
y = another.HamAn_TP
y1 = another.DukGok_TP
# y2 = another.ChilSeo_TP
# y3 = another.HwangGang_TP
# y4 = another.SanBan_TP
# y5 = another.NamGang_TP
# y6 = another.GyeaSung_TP
# y7 = another.GwangRyeo_TP
# y8 = another.ToPyeong_TP



fig, ax1 = plt.subplots(figsize=(8, 3))

ax1.plot(x, y, 'r-', label = 'HamAn_TP')
ax1.plot(x, y1, 'skyblue', label = 'DukGok_TP')
# ax1.plot(x, y2, 'orange', label = 'ChilSeo_TP')
# ax1.plot(x, y3, 'green', label = 'HwangGang_TP')
# ax1.plot(x, y4, 'skyblue', label = 'SanBan_TP')
# ax1.plot(x, y5, 'pink', label = 'NamGang_TP')
# ax1.plot(x, y6, 'purple', label = 'GyeaSung_TP')
# ax1.plot(x, y7, 'b-', label = 'GwangRyeo_TP')
# ax1.plot(x, y8, 'lightgreen', label = 'ToPyeong_TP')

ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper right')
ax1.set_ylim(0,0.18)
plt.show()

# %% [markdown]
# ##### TN

# %%
x = range(len(another.HamAn_TP))
y = another.HamAn_TN
y1 = another.DukGok_TN
# y2 = another.ChilSeo_TN
# y3 = another.HwangGang_TN
# y4 = another.SanBan_TN
# y5 = another.NamGang_TN
# y6 = another.GyeaSung_TN
# y7 = another.GwangRyeo_TN
# y8 = another.ToPyeong_TN



fig, ax1 = plt.subplots(figsize=(8, 3))

# ax2 = ax1.twinx()

ax1.plot(x, y, 'purple', label = 'HamAn_TN')
ax1.plot(x, y1, 'orange', label = 'DukGok_TN')
# ax1.plot(x, y2, 'orange', label = 'ChilSeo_TN')
# ax1.plot(x, y3, 'green', label = 'HwangGang_TN')
# ax1.plot(x, y4, 'skyblue', label = 'SanBan_TN')
# ax1.plot(x, y5, 'pink', label = 'NamGang_TN')
# ax1.plot(x, y6, 'purple', label = 'GyeaSung_TN')
# ax1.plot(x, y7, 'b-', label = 'GwangRyeo_TN')
# ax1.plot(x, y8, 'lightgreen', label = 'ToPyeong_TN')
# ax1.set_xlabel('X data')
# ax1.set_ylabel('TP(mg/L)',color='r')
# ax2.set_ylabel('강',color='b')
ax1.grid(color='#BDBDBD', linestyle='-', linewidth=0.5,)
# plt.legend(loc='upper right')
ax1.set_ylim(1,7)
plt.show()
# plt.savefig('DS_NG_TP_weather.png', dpi = 200)
# , dpi = 200
