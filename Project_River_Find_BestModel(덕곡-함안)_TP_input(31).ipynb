# %%
import pandas as pd 
import torch 
import torch.nn as nn 
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np 
import argparse
from copy import deepcopy #Add Deepcopy for args

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print(torch.__version__)
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)
# Out:
# 1.4.0
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 1. Data loading & Preprocessing

# %% [markdown]
# ### 1.1 Data loading

# %%
cd /Users/jinsungpark/Desktop
# Out:
# /Users/jinsungpark/Desktop

# %%
ls #현재경로에 있는 항목 확인
# Out:
# 2020_공모전/
# IMG_0221.png
# Input(DG)_data.xlsx
# Input(DG)_log.xlsx
# Output(HA)_data.xlsx
# Output(HA)_log.xlsx
# Python/
# TP(DG_HA)_exp01/
# Unity/
# corr_p(덕곡_함안).xlsx
# corr_s(덕곡_함안).xlsx
# etc/
# jupyter/
# result/
# result02/
# ~$덕곡_함안_상관계수.xlsx
# 과외/
# 시디1_05.pdf
# 임시/
# 졸논_서론_피드백.docx
# 덕곡_함안.xlsx
# 졸논_본문_피드백.pptx
# 덕곡_함안_상관계수.xlsx
# 시각디자인/
# 졸업논문/
# 환경공학/
# 현풍대암덕곡_데이터.xlsx
# 대암덕곡상류유사도.xlsx

# %%
UpStream_data = pd.read_excel('Input(DG)_log.xlsx')
DownStream_data = pd.read_excel('Output(HA)_log.xlsx')

# %%
# print(UpStream_data.columns)
# print(DownStream_data.columns)

# %%
#날짜 인덱스화
UpData = UpStream_data.set_index('Date')
DownData = DownStream_data.set_index('Date')

# %%
UpData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, 2013-01-07 to 2019-09-30
# Data columns (total 74 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DukGok_DO          349 non-null    float64
#  1   DukGok_BOD         349 non-null    float64
#  2   DukGok_COD         349 non-null    float64
#  3   DukGok_SS          349 non-null    float64
#  4   DukGok_TN          349 non-null    float64
#  5   DukGok_TP          349 non-null    float64
#  6   DukGok_Chl_a       349 non-null    float64
#  7   ChilSeo_COD        349 non-null    float64
#  8   ChilSeo_SS         349 non-null    float64
#  9   ChilSeo_TN         349 non-null    float64
#  10  ChilSeo_TP         349 non-null    float64
#  11  ChilSeo_Flow_mean  349 non-null    float64
#  12  ChilSeo_Flow_day   349 non-null    float64
#  13  ChilSeo_COD_load   349 non-null    float64
#  14  ChilSeo_SS_load    349 non-null    float64
#  15  ChilSeo_TN_load    349 non-null    float64
#  16  ChilSeo_TP_load    349 non-null    float64
#  17  BukChang_Rain      349 non-null    float64
#  18  BukChang_Solar     349 non-null    float64
#  19  HwangGang_DO       349 non-null    float64
#  20  HwangGang_BOD      349 non-null    float64
#  21  HwangGang_COD      349 non-null    float64
#  22  HwangGang_SS       349 non-null    float64
#  23  HwangGang_TN       349 non-null    float64
#  24  HwangGang_TP       349 non-null    float64
#  25  HwangGang_Chl_a    349 non-null    float64
#  26  HwangGang_Flow     349 non-null    float64
#  27  SanBan_DO          349 non-null    float64
#  28  SanBan_BOD         349 non-null    float64
#  29  SanBan_COD         349 non-null    float64
#  30  SanBan_SS          349 non-null    float64
#  31  SanBan_TN          349 non-null    float64
#  32  SanBan_TP          349 non-null    float64
#  33  SanBan_Chl_a       349 non-null    float64
#  34  SanBan_Flow        349 non-null    float64
#  35  NamGang_DO         349 non-null    float64
#  36  NamGang_BOD        349 non-null    float64
#  37  NamGang_COD        349 non-null    float64
#  38  NamGang_SS         349 non-null    float64
#  39  NamGang_TN         349 non-null    float64
#  40  NamGang_TP         349 non-null    float64
#  41  NamGang_Chl_a      349 non-null    float64
#  42  NamGang_Flow       349 non-null    float64
#  43  GyeaSung_DO        349 non-null    float64
#  44  GyeaSung_BOD       349 non-null    float64
#  45  GyeaSung_COD       349 non-null    float64
#  46  GyeaSung_SS        349 non-null    float64
#  47  GyeaSung_TN        349 non-null    float64
#  48  GyeaSung_TP        349 non-null    float64
#  49  GyeaSung_Chl_a     349 non-null    float64
#  50  GyeaSung_Flow      349 non-null    float64
#  51  GwangRyeo_DO       349 non-null    float64
#  52  GwangRyeo_BOD      349 non-null    float64
#  53  GwangRyeo_COD      349 non-null    float64
#  54  GwangRyeo_SS       349 non-null    float64
#  55  GwangRyeo_TN       349 non-null    float64
#  56  GwangRyeo_TP       349 non-null    float64
#  57  GwangRyeo_Chl_a    349 non-null    float64
#  58  GwangRyeo_Flow     349 non-null    float64
#  59  ToPyeong_DO        349 non-null    float64
#  60  ToPyeong_BOD       349 non-null    float64
#  61  ToPyeong_COD       349 non-null    float64
#  62  ToPyeong_SS        349 non-null    float64
#  63  ToPyeong_TN        349 non-null    float64
#  64  ToPyeong_TP        349 non-null    float64
#  65  ToPyeong_Chl_a     349 non-null    float64
#  66  ToPyeong_Flow      349 non-null    float64
#  67  DukGok_Temp        349 non-null    float64
#  68  HwangGang_Temp     349 non-null    float64
#  69  SanBan_Temp        349 non-null    float64
#  70  NamGang_Temp       349 non-null    float64
#  71  GyeaSung_Temp      349 non-null    float64
#  72  GwangRyeo_Temp     349 non-null    float64
#  73  ToPyeong_Temp      349 non-null    float64
# dtypes: float64(74)
# memory usage: 204.5+ KB

# %%
#넣고싶은 상류 항목 컬럼 선택 - TP setting(0.35기준)
UpData = UpData.iloc[:,[0,1,3,5,67,17,19,22,24,68,26,27,32,69,35,38,40,70,42,43,48,71,51,54,56,72,59,60,64,66,73]]

# %%
UpData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, 2013-01-07 to 2019-09-30
# Data columns (total 31 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DukGok_DO       349 non-null    float64
#  1   DukGok_BOD      349 non-null    float64
#  2   DukGok_SS       349 non-null    float64
#  3   DukGok_TP       349 non-null    float64
#  4   DukGok_Temp     349 non-null    float64
#  5   BukChang_Rain   349 non-null    float64
#  6   HwangGang_DO    349 non-null    float64
#  7   HwangGang_SS    349 non-null    float64
#  8   HwangGang_TP    349 non-null    float64
#  9   HwangGang_Temp  349 non-null    float64
#  10  HwangGang_Flow  349 non-null    float64
#  11  SanBan_DO       349 non-null    float64
#  12  SanBan_TP       349 non-null    float64
#  13  SanBan_Temp     349 non-null    float64
#  14  NamGang_DO      349 non-null    float64
#  15  NamGang_SS      349 non-null    float64
#  16  NamGang_TP      349 non-null    float64
#  17  NamGang_Temp    349 non-null    float64
#  18  NamGang_Flow    349 non-null    float64
#  19  GyeaSung_DO     349 non-null    float64
#  20  GyeaSung_TP     349 non-null    float64
#  21  GyeaSung_Temp   349 non-null    float64
#  22  GwangRyeo_DO    349 non-null    float64
#  23  GwangRyeo_SS    349 non-null    float64
#  24  GwangRyeo_TP    349 non-null    float64
#  25  GwangRyeo_Temp  349 non-null    float64
#  26  ToPyeong_DO     349 non-null    float64
#  27  ToPyeong_BOD    349 non-null    float64
#  28  ToPyeong_TP     349 non-null    float64
#  29  ToPyeong_Flow   349 non-null    float64
#  30  ToPyeong_Temp   349 non-null    float64
# dtypes: float64(31)
# memory usage: 87.2+ KB

# %%
# #넣고싶은 상류 항목 컬럼 선택 - TN setting
# UpData = UpData.iloc[:,[0,4,5,18,7,8,10,12,13,19,15,16,17]]
# UpData.info()

# %%
DownData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, 2013-01-07 to 2019-09-30
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   HamAn_DO     349 non-null    float64
#  1   HamAn_BOD    349 non-null    float64
#  2   HamAn_COD    349 non-null    float64
#  3   HamAn_SS     349 non-null    float64
#  4   HamAn_TN     349 non-null    float64
#  5   HamAn_TP     349 non-null    float64
#  6   HamAn_Chl_a  349 non-null    float64
# dtypes: float64(7)
# memory usage: 21.8+ KB

# %%
#알고싶은 하류 항목 컬럼 넘버 넣기('Date'항목이 인덱스화 돼서 컬럼 넘버가 -1씩 됨)
Colum = 5
print(DownData.columns[Colum])
# Out:
# HamAn_TP

# %% [markdown]
# ### 1.2 Data Preprocessing(normalization)

# %%
from sklearn.preprocessing import MinMaxScaler

UpScaler = MinMaxScaler() #상류데이터용
DownScaler = MinMaxScaler() #하류데이터용

#나중에 결과를 DeNormalizing 하기 위해 나누어 사용 하였다.

def DeNormalize(Y, Data_name, column_num, Scaler_Type):
    
    data = Data_name
    Scaler = Scaler_Type
    
    _max = Scaler.data_max_[column_num] # 역정규화 하려는 데이터의 컬럼 번호
    _min = Scaler.data_min_[column_num] 
    
    X = Y*(_max-_min) + _min
    
    return X

# %%
#데이터 정규화
UpData = pd.DataFrame(UpScaler.fit_transform(UpData), columns=UpData.columns, index=UpData.index)
DownData = pd.DataFrame(DownScaler.fit_transform(DownData), columns=DownData.columns, index=DownData.index)

print(UpData.isna().sum())
# Out:
# DukGok_DO         0
# DukGok_BOD        0
# DukGok_SS         0
# DukGok_TP         0
# DukGok_Temp       0
# BukChang_Rain     0
# HwangGang_DO      0
# HwangGang_SS      0
# HwangGang_TP      0
# HwangGang_Temp    0
# HwangGang_Flow    0
# SanBan_DO         0
# SanBan_TP         0
# SanBan_Temp       0
# NamGang_DO        0
# NamGang_SS        0
# NamGang_TP        0
# NamGang_Temp      0
# NamGang_Flow      0
# GyeaSung_DO       0
# GyeaSung_TP       0
# GyeaSung_Temp     0
# GwangRyeo_DO      0
# GwangRyeo_SS      0
# GwangRyeo_TP      0
# GwangRyeo_Temp    0
# ToPyeong_DO       0
# ToPyeong_BOD      0
# ToPyeong_TP       0
# ToPyeong_Flow     0
# ToPyeong_Temp     0
# dtype: int64

# %% [markdown]
# # 2. Data Preparation

# %%
class RiverDataset(Dataset):
    def __init__(self, UpData, DownData, x_frames, y_frames, start, end):
        
        self.x_frames = x_frames
        self.y_frames = y_frames
        
        self.start = start
        self.end = end

        self.UpData = UpData[start:end]
        self.DownData = DownData[start:end]

    def __len__(self):
        return len(self.UpData) - (self.x_frames + self.y_frames) + 1
    #데이터를 전처리 할때 UpData와 DownData의 길이가 동일해짐(날짜를 동일한것만 추출해야 하므로), 따라서 전체길이는 둘중 하나를 사용

    def __getitem__(self, idx):
        idx += self.x_frames

        X = self.UpData.iloc[idx-self.x_frames:idx].values
        Y = self.DownData.iloc[idx:idx+self.y_frames].values
        
        return X, Y

# %% [markdown]
# # 3. Model Define

# %%
class LSTM(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers, batch_size, dropout, use_bn):
        super(LSTM, self).__init__()
        self.input_dim = input_dim 
        self.hidden_dim = hidden_dim
        self.output_dim = output_dim
        self.num_layers = num_layers

        self.batch_size = batch_size
        self.dropout = dropout
        self.use_bn = use_bn 
        
        self.lstm = nn.LSTM(self.input_dim, self.hidden_dim, self.num_layers) #
        self.hidden = self.init_hidden()
        self.regressor = self.make_regressor()
        
    def init_hidden(self):
        return (torch.zeros(self.num_layers, self.batch_size, self.hidden_dim),
                torch.zeros(self.num_layers, self.batch_size, self.hidden_dim))
    
    def make_regressor(self):
        layers = []
        if self.use_bn:
            layers.append(nn.BatchNorm1d(self.hidden_dim))
        layers.append(nn.Dropout(self.dropout))
        
        layers.append(nn.Linear(self.hidden_dim, self.hidden_dim // 2))
        layers.append(nn.ReLU())
        layers.append(nn.Linear(self.hidden_dim // 2, self.output_dim))
        regressor = nn.Sequential(*layers)
        return regressor
    
    def forward(self, x):
        lstm_out, self.hidden = self.lstm(x, self.hidden)
        y_pred = self.regressor(lstm_out[-1].view(self.batch_size, -1))
        return y_pred

# %%
# 정확도 : 예측확률을 100%로 봤을때 MAPE에 따른 오차비율을 빼줌 (100-MAPE) ##RMSE, MAPE 두개로 볼 수 있게
def MAPE(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def RMSE(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred, multioutput='raw_values')
    return np.sqrt(mse)

# %%
def R2(y_true, y_pred):
    R2_score = r2_score(y_true, y_pred, multioutput='raw_values')
    return R2_score

# %% [markdown]
# # 4. Train, Validate, Test

# %%
def train(model, partition, optimizer, loss_fn, args):
    trainloader = DataLoader(partition['train'],
                             batch_size=args.batch_size,
                             shuffle=False, drop_last=True)
    model.train()
    model.zero_grad()
    optimizer.zero_grad()

    bat_siz = args.batch_size
    pred = []
    true = []
    pred_results = []
    true_results = []
    train_acc = 0.0
    train_loss = 0.0
    
    for i, (X, y) in enumerate(trainloader):

        X = X.transpose(0, 1).float().to(args.device)#파이토치는 순서가 달라서 바꿔줌
        y_true = y[:, :, Colum].float().to(args.device)
        model.zero_grad()
        optimizer.zero_grad()
        model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

        y_pred = model(X)
        loss = loss_fn(y_pred.view(-1), y_true.view(-1))
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        pred.append(y_pred)
        true.append(y_true)

    # ========================================================================== #
    for i in range(len(trainloader)):
        tems1 = pred[i].view(bat_siz).cpu().detach().numpy()
        tems2 = true[i].view(bat_siz).cpu().detach().numpy()
        
        for j in range(bat_siz):
            value1 = np.exp(DeNormalize(tems1[j], DownData, Colum, DownScaler))
            value2 = np.exp(DeNormalize(tems2[j], DownData, Colum, DownScaler))
            
            pred_results.append(value1)
            true_results.append(value2)
    # ========================================================================== #   

    train_loss = train_loss / len(trainloader)
    train_acc1 = RMSE(np.array(true_results), np.array(pred_results))
    train_acc2 = R2(np.array(true_results), np.array(pred_results))
#     train_acc3 = (100 - MAPE(np.array(true_results), np.array(pred_results)))

    return model, train_loss, train_acc1[0], train_acc2[0]

# %%
def validate(model, partition, loss_fn, args):
    valloader = DataLoader(partition['val'],
                           batch_size=args.batch_size,
                           shuffle=False, drop_last=True)
    model.eval()

    bat_siz = args.batch_size
    pred = []
    true = []
    pred_results = []
    true_results = []
    val_acc = 0.0
    val_loss = 0.0
    
    with torch.no_grad():
        for i, (X, y) in enumerate(valloader):

            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, Colum].float().to(args.device)
            model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

            y_pred = model(X)
            loss = loss_fn(y_pred.view(-1), y_true.view(-1))

            val_loss += loss.item()
            
            pred.append(y_pred)
            true.append(y_true)

        # ========================================================================== #
        for i in range(len(valloader)):
            tems1 = pred[i].view(bat_siz).cpu().detach().numpy()
            tems2 = true[i].view(bat_siz).cpu().detach().numpy()

            for j in range(bat_siz):
                value1 = np.exp(DeNormalize(tems1[j], DownData, Colum, DownScaler))
                value2 = np.exp(DeNormalize(tems2[j], DownData, Colum, DownScaler))

                pred_results.append(value1)
                true_results.append(value2)
        # ========================================================================== #   

    val_loss = val_loss / len(valloader)
    val_acc1 = RMSE(np.array(true_results), np.array(pred_results))
    val_acc2 = R2(np.array(true_results), np.array(pred_results))
#     val_acc3 = (100 - MAPE(np.array(true_results), np.array(pred_results)))

    
    return val_loss, val_acc1[0], val_acc2[0]

# %%
def test(model, partition, args):
    testloader = DataLoader(partition['test'],
                           batch_size=args.batch_size,
                           shuffle=False, drop_last=True)
    model.eval()

    bat_siz = args.batch_size
    pred = []
    true = []
    pred_results = []
    true_results = []
    test_acc = 0.0
    
    with torch.no_grad():
        for i, (X, y) in enumerate(testloader):
            X = X.transpose(0, 1).float().to(args.device)
            y_true = y[:, :, Colum].float().to(args.device)
            model.hidden = [hidden.to(args.device) for hidden in model.init_hidden()]

            y_pred = model(X)

            pred.append(y_pred)
            true.append(y_true)

    # =================== test 데이터 시각화를 위해 x,y데이터 저장 =================== #
    for i in range(len(testloader)):
        tems1 = pred[i].view(bat_siz).cpu().detach().numpy()
        tems2 = true[i].view(bat_siz).cpu().detach().numpy()
        
        for j in range(bat_siz):
            value1 = np.exp(DeNormalize(tems1[j], DownData, Colum, DownScaler))
            value2 = np.exp(DeNormalize(tems2[j], DownData, Colum, DownScaler))
            
            pred_results.append(value1)
            true_results.append(value2)
    # ======================================================================== #   

    test_acc1 =  RMSE(np.array( true_results), np.array(pred_results))
    test_acc2 =  R2(np.array( true_results), np.array(pred_results))
#     test_acc3 =  (100 - MAPE(np.array( true_results), np.array(pred_results)))
    
    return test_acc1[0], test_acc2[0], pred_results, true_results

# %% [markdown]
# # 5. Experiment

# %%
def experiment(partition, args):

    model = LSTM(args.input_dim, args.hid_dim, args.y_frames, args.n_layers, args.batch_size, args.dropout, args.use_bn)
    model.to(args.device)

    if args.loss == 'MSELoss':
        loss_fn = torch.nn.MSELoss()
        loss_fn = nn.MSELoss()
    elif args.loss == 'L1Loss':
        loss_fn = torch.nn.L1Loss()
        loss_fn = nn.L1Loss()
    elif args.loss == 'PoissonNLLLoss':
        loss_fn = torch.nn.PoissonNLLLoss()
        loss_fn = nn.PoissonNLLLoss()
    elif args.loss == 'KLDivLoss':
        loss_fn = torch.nn.KLDivLoss()
        loss_fn = nn.KLDivLoss()
    elif args.loss == 'BCELoss':
        loss_fn = torch.nn.BCELoss()
        loss_fn = nn.BCELoss()
    elif args.loss == 'BCEWithLogitsLoss':
        loss_fn = torch.nn.BCEWithLogitsLoss()
        loss_fn = nn.BCEWithLogitsLoss()
    else:
        raise ValueError('In-valid LossFuction choice')
    
    if args.optim == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')
    
    # ===== List for epoch-wise data ====== #
    train_losses = []
    val_losses = []
    train_accs_RMSE = []
    train_accs_R2 = []
    val_accs_RMSE = []
    val_accs_R2 = []
    result_info = pd.DataFrame()
    result_data = pd.DataFrame()
    
    # ===================================== #
    
    ## model starting point ##    
    ts = time.time()
    model, train_loss, train_acc_RMSE, train_acc_R2 = train(model, partition, optimizer, loss_fn, args)
    val_loss, val_acc_RMSE, val_acc_R2 = validate(model, partition, loss_fn, args)
    te = time.time()

    # ====== Add Epoch Data ====== #
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs_RMSE.append(train_acc_RMSE)
    val_accs_RMSE.append(val_acc_RMSE)
    train_accs_R2.append(train_acc_R2)
    val_accs_R2.append(val_acc_R2)
    # ============================ #


#     print('Epoch {}, Acc_RMSE(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.5f}/{:2.5f}. Took {:2.2f} sec'
#           .format(0, train_acc_RMSE, val_acc_RMSE, train_loss, val_loss, te-ts))
    
    for epoch in range(args.epoch-1):  # loop over the dataset multiple times
        
        ts = time.time()
        model, train_loss, train_acc_RMSE, train_acc_R2 = train(model, partition, optimizer, loss_fn, args)
        val_loss, val_acc_RMSE, val_acc_R2 = validate(model, partition, loss_fn, args)
        te = time.time()

        # ====== Add Epoch Data ====== #
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs_RMSE.append(train_acc_RMSE)
        val_accs_RMSE.append(val_acc_RMSE)
        train_accs_R2.append(train_acc_R2)
        val_accs_R2.append(val_acc_R2)
        # ============================ #
        
        
        if epoch == epoch:
            trash_01, trash_02, Pred_save, True_save = test(model, partition, args)
            result_data['test_pred_epoch({})'.format(epoch)] = Pred_save
            result_data['test_true_epoch({})'.format(epoch)] = True_save


#         print('Epoch {}, Acc_RMSE(train/val): {:2.4f}/{:2.4f}, Loss(train/val) {:2.5f}/{:2.5f}. Took {:2.2f} sec'
#               .format(epoch+1, train_acc_RMSE, val_acc_RMSE, train_loss, val_loss, te-ts))
        
    test_acc_RMSE, test_acc_R2, Pred_data, True_data = test(model, partition, args)    
    
    # ======= Add Result  ======= #
    result_info['train_losses'] = train_losses
    result_info['val_losses'] = val_losses
    
    result_info['train_accs_RMSE'] = train_accs_RMSE
    result_info['train_accs_R2'] = train_accs_R2
    result_info['val_accs_RMSE'] = val_accs_RMSE
    result_info['val_accs_R2'] = val_accs_R2
    
#     result_info['train_acc'] = train_acc
#     result_info['val_acc'] = val_acc
    result_info['test_RMSE'] = test_acc_RMSE
    result_info['test_R2'] = test_acc_R2

#     result_data['test_pred'] = Pred_data
#     result_data['test_true'] = True_data
    
    return result_info, result_data

# %% [markdown]
# # 6. LSTM Run

# %%
# ====== Random Seed Initialization ====== #
seed = 666
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")

args.device = 'cuda' if torch.cuda.is_available() else 'cpu'

# ====== Data Loading ====== #
args.batch_size = 8
args.UpData = UpData
args.DownData = DownData
args.x_frames = 5
args.y_frames = 1

# ====== Model Capacity ===== #
args.input_dim = len(UpData.columns)
args.hid_dim = 16
args.n_layers = 2

# ====== Regularization ======= #
args.l2 = 0.0001
args.dropout = 0.1 
args.use_bn = False

# ====== Optimizer & Training ====== #
args.optim = 'Adam'  #SGD, RMSprop, Adam...
args.loss = 'MSELoss'#'MSELoss','L1Loss','PoissonNLLLoss','KLDivLoss','BCELoss','BCEWithLogitsLoss'
args.lr = 0.01
args.epoch = 3


# ====== Experiment Variable ====== #
name_var1 = 'x_frames'
list_var1 = [4,2]

name_var2 = 'loss'
list_var2 = ['MSELoss']

name_var3 = 'optim'
list_var3 = ['Adam']

name_var4 = 'use_bn'
list_var4 = [False]

name_var5 = 'dropout'
list_var5 = [0.1]

name_var6 = 'batch_size'
list_var6 = [4, 8]

name_var7 = 'hid_dim'
list_var7 = [32, 16]

name_var8 = 'n_layers'
list_var8 = [4, 3, 2]

name_var9 = 'lr'
list_var9 = [0.01, 0.001, 0.0001]

name_var10 = 'l2'
list_var10 = [0.01, 0.001,0.0001]

name_var11 = 'epoch'
list_var11 = [200]

trainset = RiverDataset(args.UpData, args.DownData, args.x_frames, args.y_frames, '2013-01-01', '2018-06-30')
valset = RiverDataset(args.UpData, args.DownData, args.x_frames, args.y_frames, '2018-07-01', '2019-12-31')
testset = RiverDataset(args.UpData, args.DownData, args.x_frames, args.y_frames, '2018-07-01', '2019-12-31')
partition = {'train': trainset, 'val':valset, 'test':testset}

print(' size of trainset :{}\n'.format(len(trainset)),
      'size of valset :{}\n'.format(len(valset)),
      'size of testset :{}'.format(len(testset)))

list_vars = [list_var1, list_var2, list_var3, list_var4, list_var5, list_var6, list_var7, list_var8, list_var9, list_var10, list_var11]
i = 1
for lenth in list_vars:
    x = len(lenth)
    i *= x
total_exp_num = i

print(' total_exp_num : {}'.format(total_exp_num))
# Out:
#  size of trainset :279
#  size of valset :60
#  size of testset :60
#  total_exp_num : 216

# %%
pwd
# Out:
# '/Users/jinsungpark/Desktop'

# %%
cd /Users/jinsungpark/Desktop/TP(DG_HA)_exp02
# Out:
# /Users/jinsungpark/Desktop/TP(DG_HA)_exp02

# %%
seed = 666
np.random.seed(seed)
torch.manual_seed(seed)

print('##### Start #####')

num = 0 #초기화

for var1 in list_var1:
    for var2 in list_var2:
        for var3 in list_var3:
            for var4 in list_var4:
                for var5 in list_var5:
                    for var6 in list_var6:
                        for var7 in list_var7:
                            for var8 in list_var8:
                                for var9 in list_var9:
                                    for var10 in list_var10:
                                        for var11 in list_var11:
                                            ts = time.time()
                                            num += 1
                                            setattr(args, name_var1, var1)
                                            setattr(args, name_var2, var2)
                                            setattr(args, name_var3, var3)
                                            setattr(args, name_var4, var4)
                                            setattr(args, name_var5, var5)
                                            setattr(args, name_var6, var6)
                                            setattr(args, name_var7, var7)
                                            setattr(args, name_var8, var8)
                                            setattr(args, name_var9, var9)
                                            setattr(args, name_var10, var10)
                                            setattr(args, name_var11, var11)

#                                             print('experiment_{}/{} : x_frames = {}, loss={}, optim={}, use_bn={}, dropout={}, batch_size={}, hid_dim={}, n_layers={}, lr={}, l2={}, epoch={}'
#                                                   .format(num,total_exp_num,args.x_frames,args.loss,args.optim,args.use_bn,args.dropout,args.batch_size,args.hid_dim,args.n_layers,args.lr,args.l2,args.epoch))
                                            result_info, result_data = experiment(partition, deepcopy(args))
    
                                            min_RMSE = min(result_info['val_accs_RMSE'])
                                            max_R2 = max(result_info['val_accs_R2'])
#                                             RMSE_ = result_info['val_accs_RMSE']
#                                             R2_ = result_info['val_accs_R2']
                                            epoch = args.epoch
                                            
                                            result_info.to_csv('exp{:03d}_info_RMSE[{:2.4f}]_R2[{:2.4f}].csv'.format(num,min_RMSE,max_R2))
                                            result_data.to_csv('exp{:03d}_data_RMSE[{:2.4f}]_R2[{:2.4f}].csv'.format(num,min_RMSE,max_R2))
                
                                            file=open('exp_index.txt','a')
                                            file.write('experiment {:03d}/{} : x_frames = {}, loss={}, optim={}, use_bn={}, dropout={}, batch_size={}, hid_dim={}, n_layers={}, lr={}, l2={}, epoch={}\n'
                                                       .format(num,total_exp_num,args.x_frames,args.loss,args.optim,args.use_bn,args.dropout,args.batch_size,args.hid_dim,args.n_layers,args.lr,args.l2,args.epoch))
                                            file.close()

                                            te = time.time()
                                
                                            print('experiment_{}/{}, took {:2.1f}sec, {:2.2f}% done'
                                                  .format(num,total_exp_num,te-ts,(num/total_exp_num)*100))
                                    
#                                             network = LSTM(args.input_dim, args.hid_dim, args.y_frames, args.n_layers, args.batch_size, args.dropout, args.use_bn)
#                                             torch.save(network.state_dict(),'lstm1.pt')
                            
                                       
#                                             print('train_acc = {:2.2f}%, val_acc = {:2.2f}%, test_acc = {:2.2f}%'
#                                                   .format(result['train_acc'],result['val_acc'],result['test_acc']))

print('All done')
# Out:
# ##### Start #####
# experiment_1/216, took 221.6sec, 0.46% done
# experiment_2/216, took 231.1sec, 0.93% done
# experiment_3/216, took 188.8sec, 1.39% done
# experiment_4/216, took 137.0sec, 1.85% done
# experiment_5/216, took 90.3sec, 2.31% done
# experiment_6/216, took 89.9sec, 2.78% done
# experiment_7/216, took 113.4sec, 3.24% done
# experiment_8/216, took 90.7sec, 3.70% done
# experiment_9/216, took 89.8sec, 4.17% done
# experiment_10/216, took 93.3sec, 4.63% done
# experiment_11/216, took 99.7sec, 5.09% done
# experiment_12/216, took 93.9sec, 5.56% done
# experiment_13/216, took 109.4sec, 6.02% done
# experiment_14/216, took 73.9sec, 6.48% done
# experiment_15/216, took 75.3sec, 6.94% done
# experiment_16/216, took 97.0sec, 7.41% done
# experiment_17/216, took 76.2sec, 7.87% done
# experiment_18/216, took 75.7sec, 8.33% done
# experiment_19/216, took 78.4sec, 8.80% done
# experiment_20/216, took 59.1sec, 9.26% done
# experiment_21/216, took 59.1sec, 9.72% done
# experiment_22/216, took 59.3sec, 10.19% done
# experiment_23/216, took 61.1sec, 10.65% done
# experiment_24/216, took 58.5sec, 11.11% done
# experiment_25/216, took 60.2sec, 11.57% done
# experiment_26/216, took 58.7sec, 12.04% done
# experiment_27/216, took 58.8sec, 12.50% done
# experiment_28/216, took 99.3sec, 12.96% done
# experiment_29/216, took 103.5sec, 13.43% done
# experiment_30/216, took 103.0sec, 13.89% done
# experiment_31/216, took 111.9sec, 14.35% done
# experiment_32/216, took 85.7sec, 14.81% done
# experiment_33/216, took 85.9sec, 15.28% done
# experiment_34/216, took 96.2sec, 15.74% done
# experiment_35/216, took 85.7sec, 16.20% done
# experiment_36/216, took 85.5sec, 16.67% done
# experiment_37/216, took 77.5sec, 17.13% done
# experiment_38/216, took 82.3sec, 17.59% done
# experiment_39/216, took 74.1sec, 18.06% done
# experiment_40/216, took 84.7sec, 18.52% done
# experiment_41/216, took 72.4sec, 18.98% done
# experiment_42/216, took 71.8sec, 19.44% done
# experiment_43/216, took 75.5sec, 19.91% done
# experiment_44/216, took 68.5sec, 20.37% done
# experiment_45/216, took 68.0sec, 20.83% done
# experiment_46/216, took 68.3sec, 21.30% done
# experiment_47/216, took 82.1sec, 21.76% done
# experiment_48/216, took 84.0sec, 22.22% done
# experiment_49/216, took 81.1sec, 22.69% done
# experiment_50/216, took 89.8sec, 23.15% done
# experiment_51/216, took 127.1sec, 23.61% done
# experiment_52/216, took 133.7sec, 24.07% done
# experiment_53/216, took 126.9sec, 24.54% done
# experiment_54/216, took 127.2sec, 25.00% done
# experiment_55/216, took 189.6sec, 25.46% done
# experiment_56/216, took 183.5sec, 25.93% done
# experiment_57/216, took 166.0sec, 26.39% done
# experiment_58/216, took 185.1sec, 26.85% done
# experiment_59/216, took 132.9sec, 27.31% done
# experiment_60/216, took 133.2sec, 27.78% done
# experiment_61/216, took 148.5sec, 28.24% done
# experiment_62/216, took 138.9sec, 28.70% done
# experiment_63/216, took 138.0sec, 29.17% done
# experiment_64/216, took 159.6sec, 29.63% done
# experiment_65/216, took 135.8sec, 30.09% done
# experiment_66/216, took 134.4sec, 30.56% done
# experiment_67/216, took 149.3sec, 31.02% done
# experiment_68/216, took 117.9sec, 31.48% done
# experiment_69/216, took 106.0sec, 31.94% done
# experiment_70/216, took 73.1sec, 32.41% done
# experiment_71/216, took 69.4sec, 32.87% done
# experiment_72/216, took 69.8sec, 33.33% done
# experiment_73/216, took 73.9sec, 33.80% done
# experiment_74/216, took 57.0sec, 34.26% done
# experiment_75/216, took 57.3sec, 34.72% done
# experiment_76/216, took 57.4sec, 35.19% done
# experiment_77/216, took 57.0sec, 35.65% done
# experiment_78/216, took 64.7sec, 36.11% done
# experiment_79/216, took 88.0sec, 36.57% done
# experiment_80/216, took 88.0sec, 37.04% done
# experiment_81/216, took 88.3sec, 37.50% done
# experiment_82/216, took 115.2sec, 37.96% done
# experiment_83/216, took 109.8sec, 38.43% done
# experiment_84/216, took 107.4sec, 38.89% done
# experiment_85/216, took 110.0sec, 39.35% done
# experiment_86/216, took 90.1sec, 39.81% done
# experiment_87/216, took 89.9sec, 40.28% done
# experiment_88/216, took 90.4sec, 40.74% done
# experiment_89/216, took 89.8sec, 41.20% done
# experiment_90/216, took 89.8sec, 41.67% done
# experiment_91/216, took 91.9sec, 42.13% done
# experiment_92/216, took 92.3sec, 42.59% done
# experiment_93/216, took 75.9sec, 43.06% done
# experiment_94/216, took 90.2sec, 43.52% done
# experiment_95/216, took 75.9sec, 43.98% done
# experiment_96/216, took 76.1sec, 44.44% done
# experiment_97/216, took 76.1sec, 44.91% done
# experiment_98/216, took 75.9sec, 45.37% done
# experiment_99/216, took 75.8sec, 45.83% done
# experiment_100/216, took 74.8sec, 46.30% done
# experiment_101/216, took 62.6sec, 46.76% done
# experiment_102/216, took 62.1sec, 47.22% done
# experiment_103/216, took 62.1sec, 47.69% done
# experiment_104/216, took 61.9sec, 48.15% done
# experiment_105/216, took 61.9sec, 48.61% done
# experiment_106/216, took 61.9sec, 49.07% done
# experiment_107/216, took 61.8sec, 49.54% done
# experiment_108/216, took 61.8sec, 50.00% done
# experiment_109/216, took 221.6sec, 50.46% done
# experiment_110/216, took 240.0sec, 50.93% done
# experiment_111/216, took 224.0sec, 51.39% done
# experiment_112/216, took 253.4sec, 51.85% done
# experiment_113/216, took 163.5sec, 52.31% done
# experiment_114/216, took 163.2sec, 52.78% done
# experiment_115/216, took 205.7sec, 53.24% done
# experiment_116/216, took 162.7sec, 53.70% done
# experiment_117/216, took 162.8sec, 54.17% done
# experiment_118/216, took 177.4sec, 54.63% done
# experiment_119/216, took 179.7sec, 55.09% done
# experiment_120/216, took 170.2sec, 55.56% done
# experiment_121/216, took 199.2sec, 56.02% done
# experiment_122/216, took 134.1sec, 56.48% done
# experiment_123/216, took 134.0sec, 56.94% done
# experiment_124/216, took 174.9sec, 57.41% done
# experiment_125/216, took 134.0sec, 57.87% done
# experiment_126/216, took 133.9sec, 58.33% done
# experiment_127/216, took 131.6sec, 58.80% done
# experiment_128/216, took 105.1sec, 59.26% done
# experiment_129/216, took 104.7sec, 59.72% done
# experiment_130/216, took 106.4sec, 60.19% done
# experiment_131/216, took 104.7sec, 60.65% done
# experiment_132/216, took 128.4sec, 61.11% done
# experiment_133/216, took 142.8sec, 61.57% done
# experiment_134/216, took 143.9sec, 62.04% done
# experiment_135/216, took 144.8sec, 62.50% done
# experiment_136/216, took 246.6sec, 62.96% done
# experiment_137/216, took 254.2sec, 63.43% done
# experiment_138/216, took 247.5sec, 63.89% done
# experiment_139/216, took 259.4sec, 64.35% done
# experiment_140/216, took 248.0sec, 64.81% done
# experiment_141/216, took 220.1sec, 65.28% done
# experiment_142/216, took 240.1sec, 65.74% done
# experiment_143/216, took 228.7sec, 66.20% done
# experiment_144/216, took 223.8sec, 66.67% done
# experiment_145/216, took 199.1sec, 67.13% done
# experiment_146/216, took 206.9sec, 67.59% done
# experiment_147/216, took 182.8sec, 68.06% done
# experiment_148/216, took 204.9sec, 68.52% done
# experiment_149/216, took 180.7sec, 68.98% done
# experiment_150/216, took 133.3sec, 69.44% done
# experiment_151/216, took 136.0sec, 69.91% done
# experiment_152/216, took 130.8sec, 70.37% done
# experiment_153/216, took 132.4sec, 70.83% done
# experiment_154/216, took 153.1sec, 71.30% done
# experiment_155/216, took 154.0sec, 71.76% done
# experiment_156/216, took 142.2sec, 72.22% done
# experiment_157/216, took 142.5sec, 72.69% done
# experiment_158/216, took 141.7sec, 73.15% done
# experiment_159/216, took 142.7sec, 73.61% done
# experiment_160/216, took 143.3sec, 74.07% done
# experiment_161/216, took 142.5sec, 74.54% done
# experiment_162/216, took 94.4sec, 75.00% done
# experiment_163/216, took 131.2sec, 75.46% done
# experiment_164/216, took 125.2sec, 75.93% done
# experiment_165/216, took 114.7sec, 76.39% done
# experiment_166/216, took 147.5sec, 76.85% done
# experiment_167/216, took 97.6sec, 77.31% done
# experiment_168/216, took 96.6sec, 77.78% done
# experiment_169/216, took 97.1sec, 78.24% done
# experiment_170/216, took 92.8sec, 78.70% done
# experiment_171/216, took 121.1sec, 79.17% done
# experiment_172/216, took 127.1sec, 79.63% done
# experiment_173/216, took 80.3sec, 80.09% done
# experiment_174/216, took 96.6sec, 80.56% done
# experiment_175/216, took 102.7sec, 81.02% done
# experiment_176/216, took 75.3sec, 81.48% done
# experiment_177/216, took 70.5sec, 81.94% done
# experiment_178/216, took 73.2sec, 82.41% done
# experiment_179/216, took 70.0sec, 82.87% done
# experiment_180/216, took 69.0sec, 83.33% done
# experiment_181/216, took 72.2sec, 83.80% done
# experiment_182/216, took 56.1sec, 84.26% done
# experiment_183/216, took 56.3sec, 84.72% done
# experiment_184/216, took 66.5sec, 85.19% done
# experiment_185/216, took 88.7sec, 85.65% done
# experiment_186/216, took 88.0sec, 86.11% done
# experiment_187/216, took 88.3sec, 86.57% done
# experiment_188/216, took 88.6sec, 87.04% done
# experiment_189/216, took 87.2sec, 87.50% done
# experiment_190/216, took 115.8sec, 87.96% done
# experiment_191/216, took 110.0sec, 88.43% done
# experiment_192/216, took 105.2sec, 88.89% done
# experiment_193/216, took 109.6sec, 89.35% done
# experiment_194/216, took 105.2sec, 89.81% done
# experiment_195/216, took 89.4sec, 90.28% done
# experiment_196/216, took 89.6sec, 90.74% done
# experiment_197/216, took 89.4sec, 91.20% done
# experiment_198/216, took 89.4sec, 91.67% done
# experiment_199/216, took 92.6sec, 92.13% done
# experiment_200/216, took 90.4sec, 92.59% done
# experiment_201/216, took 75.8sec, 93.06% done
# experiment_202/216, took 90.1sec, 93.52% done
# experiment_203/216, took 75.5sec, 93.98% done
# experiment_204/216, took 75.3sec, 94.44% done
# experiment_205/216, took 75.3sec, 94.91% done
# experiment_206/216, took 75.2sec, 95.37% done
# experiment_207/216, took 75.1sec, 95.83% done
# experiment_208/216, took 73.4sec, 96.30% done
# experiment_209/216, took 61.3sec, 96.76% done
# experiment_210/216, took 61.4sec, 97.22% done
# experiment_211/216, took 61.6sec, 97.69% done
# experiment_212/216, took 62.0sec, 98.15% done
# experiment_213/216, took 61.4sec, 98.61% done
# experiment_214/216, took 61.4sec, 99.07% done
# experiment_215/216, took 61.4sec, 99.54% done
# experiment_216/216, took 61.4sec, 100.00% done
# All done
