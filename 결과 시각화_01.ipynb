# %%
pwd
# Out:
# '/Users/jinsungpark/Desktop/jupyter'

# %%
cd /Users/jinsungpark/Desktop
# Out:
# /Users/jinsungpark/Desktop

# %%
# ls

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.collections as collections

# %matplotlib inline

# %%
dfA = pd.read_excel('/Users/jinsungpark/Desktop/졸업논문바탕화면백업/RiverLast/1.입력데이터모음/1.다사-논공/NG_Data_edit.xlsx')
# dfB = pd.read_excel('/Users/jinsungpark/Desktop/RiverLast/1.입력데이터모음/2.현풍-대암-덕곡/현풍-대암/DA_Down_data.xlsx')
# dfC = pd.read_excel('/Users/jinsungpark/Desktop/RiverLast/1.입력데이터모음/2.현풍-대암-덕곡/대암-덕곡/DG_Down_data.xlsx')
dfD = pd.read_excel('/Users/jinsungpark/Desktop/졸업논문바탕화면백업/RiverLast/1.입력데이터모음/3.덕곡-함안/Output(HA)_data.xlsx')

# %%
A_TP = dfA.NG_TP
A_TN = dfA.NG_TN
A_Date = dfA.Date
# B_TP = dfB.DA_TP
# B_TN = dfB.DA_TN
# B_Date = dfB.Date
# C_TP = dfC.DG_TP
# C_TN = dfC.DG_TN
# C_Date = dfC.Date
D_TP = dfD.HamAn_TP
D_TN = dfD.HamAn_TN
D_Date = dfD.Date

# %%
D_Date
# Out:
# 0      2013-01-07
# 1      2013-01-14
# 2      2013-01-21
# 3      2013-01-28
# 4      2013-02-04
#           ...
# 344    2019-09-02
# 345    2019-09-09
# 346    2019-09-16
# 347    2019-09-24
# 348    2019-09-30
# Name: Date, Length: 349, dtype: object

# %%
x1 = range(349)
x2 = range(227)
x3 = range(265)

# %%
fig, axs = plt.subplots(4, 1, figsize=(20, 17))

axs[0].plot(x2, A_TP, color='black')
# axs[0].set_xlim(0, 349)
# axs[0].set_xlabel('time')
# axs[0].xticks(rotation=45)
# axs[0,0].set_ylabel('NonGong')
# axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=45)
axs[0].grid(False)
axs[0].axvspan(0, max(x2)*0.8, color='tab:blue', alpha=0.07)
axs[0].axvspan(max(x2)*0.8, max(x2), color='tab:red', alpha=0.07)

axs[1].plot(x2, A_TN, color='black')
# axs[1].set_xlim(0, 349)
# axs[0,1].set_xlabel('time')
# axs[0,1].set_ylabel('NonGong')
axs[1].grid(False)
axs[1].axvspan(0, max(x2)*0.8, color='tab:blue', alpha=0.07)
axs[1].axvspan(max(x2)*0.8, max(x2), color='tab:red', alpha=0.07)

# axs[1,0].plot(x3, B_TP, color='black')
# axs[1,0].set_xlim(0, max(x3))
# # axs[1,0].set_xlabel('time')
# # axs[1,0].set_ylabel('NonGong')
# axs[1,0].grid(False)
# axs[1,0].axvspan(0, max(x3)*0.8, color='tab:blue', alpha=0.15)
# axs[1,0].axvspan(max(x3)*0.8, max(x3), color='tab:red', alpha=0.15)

# axs[1,1].plot(x3, B_TN, color='black')
# axs[1,1].set_xlim(0, max(x3))
# # axs[1,1].set_xlabel('time')
# # axs[1,1].set_ylabel('NonGong')
# axs[1,1].grid(False)
# axs[1,1].axvspan(0, max(x3)*0.8, color='tab:blue', alpha=0.15)
# axs[1,1].axvspan(max(x3)*0.8, max(x3), color='tab:red', alpha=0.15)

# axs[2,0].plot(x3, C_TP, color='black')
# axs[2,0].set_xlim(0, max(x3))
# # axs[2,0].set_xlabel('time')
# # axs[2,0].set_ylabel('NonGong')
# axs[2,0].grid(False)
# axs[2,0].axvspan(0, max(x3), color='tab:red', alpha=0.15)
# # axs[2,0].axvspan(max(x3)*0.8, max(x3), color='red', alpha=0.15)

# axs[2,1].plot(x3, C_TN, color='black')
# axs[2,1].set_xlim(0, max(x3))
# # axs[2,1].set_xlabel('time')
# # axs[2,1].set_ylabel('NonGong')
# axs[2,1].grid(False)
# axs[2,1].axvspan(0, max(x3), color='tab:red', alpha=0.15)
# # axs[2,1].axvspan(max(x3)*0.8, max(x3), color='red', alpha=0.15)

axs[2].plot(x1, D_TP, color='black')
axs[2].set_xlim(0, 349)
# axs[3,0].set_xlabel('time')
# axs[3,0].set_ylabel('NonGong')
axs[2].grid(False)
axs[2].axvspan(0, max(x1)*0.8, color='tab:blue', alpha=0.07)
axs[2].axvspan(max(x1)*0.8, max(x1), color='tab:red', alpha=0.07)

axs[3].plot(x1, D_TN, color='black')
axs[3].set_xlim(0, 349)
# axs[3,1].set_xlabel('time')
# axs[3,1].set_ylabel('NonGong')
axs[3].grid(False)
axs[3].axvspan(0, max(x1)*0.8, color='tab:blue', alpha=0.07)
axs[3].axvspan(max(x1)*0.8, max(x1), color='tab:red', alpha=0.07)


# fig.savefig('data.png', dpi = 200,  bbox_inches='tight')

# %%
pwd
# Out:
# '/Users/jinsungpark/Desktop'
